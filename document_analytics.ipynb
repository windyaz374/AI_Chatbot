# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings
from chromadb.config import Settings
from langchain_community.vectorstores.chroma import Chroma

setting = Settings(
    anonymized_telemetry=False,
    is_persistent=True,
)

embeddings = OllamaEmbeddings(model="phi3")

vector_store = Chroma(
    persist_directory='.DB',
    embedding_function=embeddings,
    client_settings=setting,
)

# %%
docs = vector_store.get()
docs
# Out:
# {'ids': ['00b54202-f2a2-4e18-9165-8f809ae0b928',
#   '028934ec-cad2-42c2-bd29-6601b524c24e',
#   '028bb222-a38d-4416-8626-8998dd2646d5',
#   '035c8e10-f390-4ad6-ab76-fe4a1212bf1e',
#   '03ab66b6-ca9f-4b75-94fd-217b9ddc40ec',
#   '05606d0c-2ba9-4292-a19a-926ff849306d',
#   '059b3443-6938-4ec3-bfad-6bb28661b963',
#   '08916e50-b404-448e-ab29-5c8b359b124a',
#   '0d192548-bcfc-438b-9f1c-50b837506c88',
#   '0f52864f-328b-4d40-b192-c326636c394c',
#   '0ff7f3c8-0b94-475e-a109-9f12808f2e39',
#   '101ee384-c1d1-40e1-8e51-92e87c71d035',
#   '1083e26f-8e14-47fb-96ca-d054ed7751fa',
#   '11c23770-8dd1-4192-9e0a-e4f01de116d7',
#   '13eab5dc-2bbd-4abe-9db1-b3b525e0e68a',
#   '143bcce7-5e08-4e9d-a877-3224da45e170',
#   '15411f1c-5c8c-4fef-923e-2653ed707550',
#   '1571f7fb-a950-49ab-a5e0-f49a26294b2c',
#   '17a6e0c2-5d8c-4e64-b4f4-6cc153f271f0',
#   '181c25a4-59bf-4cfa-bf55-9fef1758d194',
#   '1b2272f4-d8b3-4a12-b7f0-e17da25a6dce',
#   '1cc42f31-80c9-4be8-9e96-df6975f5b50a',
#   '1d04b0b7-ae4a-476e-ad5d-7bd600b8c45a',
#   '1eba124a-931e-42c1-837e-c9804bb4583e',
#   '1fe60142-fdf9-40c2-a849-df371cce9b6d',
#   '212dfce6-ac88-4639-b6f8-617de0cea747',
#   '2498f19f-b46b-4762-99e1-71c8ee512711',
#   '26b6cc5c-b089-4ec3-9e03-39f8305d0b99',
#   '28527969-d4b8-4781-b5e1-1bd7573ac921',
#   '29d25d30-c274-4aaa-8593-7f517946a613',
#   '2c6d0689-ebdc-4b77-a5d5-0b2e890dd9fb',
#   '2d6178f0-25f2-4b42-b94c-5e374c8b648b',
#   '2e640055-9724-4111-8025-4b626ccfbbca',
#   '30a76fdd-32f4-4857-ac0c-9a71dcf8d7e5',
#   '32b6f8f9-3f07-4345-b0eb-1b49e4fca6f8',
#   '3816b89d-a22b-4a62-8b7d-04ea72c1d238',
#   '3ddab9ff-d86f-4be6-a308-2a31d9d1b074',
#   '3f6861df-1d10-44e2-95ca-ab30d7e19e81',
#   '3ffbf25d-943a-4071-b50e-ea53a1bccd03',
#   '40b2c3dc-a32f-4fdd-b49d-a639c533d244',
#   '40dc1e08-9805-46ed-92b4-ed546ecd98e5',
#   '41dd95ce-141a-4837-931b-54216990aeb8',
#   '4728d2fe-1b52-439a-b271-ed631b7e76fa',
#   '47dd7155-9a11-4405-b6f4-a755b2bf78e3',
#   '4a387424-7a4a-41d3-b1b7-77982f113c8b',
#   '4b3e3743-773c-4d60-9924-e9dbc09b99ab',
#   '4e6ae607-db5d-4ed8-b53e-eb84a80806b4',
#   '4fe70ca4-ab79-442b-85b4-18a61b5df572',
#   '52c2b7ee-490f-40bc-bf93-883068bdfb1c',
#   '531a9b9a-cd31-4a7a-bfa5-60d17e93913e',
#   '531fac70-f8e9-498c-ac49-0d30780273d6',
#   '54f1c699-6cb4-4510-8329-7bf0c66b7978',
#   '56509ecc-9440-4d1d-b76c-cd200c71606b',
#   '57ddfdc6-6d8a-4fcf-8f08-8983c775cd8c',
#   '59517a17-19e1-4ab3-9df2-daaabdaab690',
#   '5bd30833-10d2-44a8-8738-cbc0f0378d91',
#   '5bf9c4f6-77ec-4c61-b240-5b5e7c2bdeb7',
#   '6192f6e5-0d80-4bfc-a87d-7bb921535000',
#   '62244d8a-f14d-48fe-9e5f-4214a47abbed',
#   '693932e0-5261-461c-8597-854ceabe3285',
#   '6a06e94c-87c9-4579-b67d-652499f453cf',
#   '6c897e57-b890-47a9-9554-1212f05d4676',
#   '6c99fe53-1c07-4573-b463-0bb086c6d3ca',
#   '739bd32c-6b00-44a8-90a9-a0af805da201',
#   '761db3a3-6e3e-4712-ab0c-09a0be3d4605',
#   '78e3b112-c3d2-4d25-9abe-b40634788bb6',
#   '79a2e7ca-deb7-4585-85a5-0c31f2994e09',
#   '79fa2564-a6bd-45b4-8b6b-243545c46462',
#   '7f964de2-8bb7-4f08-b562-54f9a1f84c5f',
#   '80eeb8d5-4285-49a3-b5db-496b3314e630',
#   '81fd153c-e03a-4883-9c5c-d7caeb9783d8',
#   '821b21fb-fdf8-41e9-bd90-3f4de6beb278',
#   '88ed9f04-d85f-493e-99d3-680930166518',
#   '90458298-5a66-4d7f-9865-746be9e1a606',
#   '914eff3a-e785-4709-a409-0d8c58087ffc',
#   '91d67f10-479d-4306-8228-c3d03703f806',
#   '935693af-aefa-4898-b3c2-0ea249e8b76d',
#   '96040e49-f41e-40b7-9392-22a6b7be40da',
#   '965da4b9-0796-4903-b4b4-e2c766b87953',
#   '983ae33a-7f88-4638-8c57-38109a683391',
#   '99771efe-ba1c-4c9e-812e-ef4295186172',
#   '9c3a39b7-5267-45f4-9eb6-fcedab7f9971',
#   '9e1a0ca8-6488-46cb-87a0-921c1a3fd0b2',
#   '9ea64111-804e-41ae-ab13-adb5f264d74c',
#   '9f5c3dc0-52ab-4647-86c8-7d8443ead04d',
#   'a190129f-b471-47c2-8fa7-0ce0a217405f',
#   'a3e1d8a6-c0ef-4129-b324-2860e0356c82',
#   'a6b1f735-3fdd-42c2-a6ea-c3bcf4d7a31c',
#   'a83851d0-c979-450a-be6c-ef14d3c5767c',
#   'a839f6b1-2699-49c1-bc72-edeab9820b9f',
#   'aa95a12d-6140-4660-965b-caa38eaf1fa3',
#   'ab1571f1-9cd2-48c7-88a7-6dd4e7c8055c',
#   'ac18d1b9-30da-4ee0-84b4-2197438998a6',
#   'ad1dd2d0-2c75-4a70-be1f-14bac24db0ba',
#   'b20e6316-59d6-4263-b52a-b46a716e4e85',
#   'b30f9d6d-bd35-40fd-baec-98f84f260f3d',
#   'b486f658-c1be-44aa-8962-c3d9db0d874f',
#   'b4c47730-2827-42f4-996a-25109b0554c7',
#   'b6c2e66c-462a-453f-8171-2d1068fc56b1',
#   'b95bf6cb-db6c-495b-b1c5-cac5dd8513e4',
#   'b9a8244e-8119-47ae-9132-5cf5a74a8465',
#   'beb2704b-7078-46d9-881d-0e80bb4de589',
#   'bfc769ef-57b8-459e-8fe4-511363b7c109',
#   'c06cbce9-cc5d-45bf-99f1-0df2c59a62a1',
#   'c142217b-13de-4408-9e9a-7f7b083da762',
#   'c174a913-87de-41b4-a5b3-5917af3adc62',
#   'c5aaccc0-c4b9-4fd0-a79d-bc8baf0a2724',
#   'c660360e-3874-4ca9-9437-4749263190df',
#   'c773f1fa-acf8-4033-8802-4a3df28038dd',
#   'cb8f4f98-0f76-4b6e-afe9-5ee334b8f00a',
#   'cc029ca8-6946-4566-b812-a9dd0ec4e528',
#   'cd2f5a47-b959-4b4a-b9d8-8d3769480fd0',
#   'cd9bc71d-b407-4e7b-bd7b-e26202470ee6',
#   'ce0f947b-6f21-4553-842c-9ab174a53195',
#   'cf5004d6-3eea-404c-b405-f445ac559640',
#   'd555cd30-a93e-42eb-ba6c-8003cbca432e',
#   'd69909e5-c162-4ea1-8d0e-4aa7809cbe91',
#   'd6f0cc35-c709-413b-a5a0-935c80eed020',
#   'd81f425f-0b42-4c10-92fc-da3279570fab',
#   'ddf18758-8142-4a3e-8952-376a7c57d4c9',
#   'e105b69c-1489-4a91-8934-e592444f284c',
#   'e2e9b89d-8bfa-4f64-900c-3067c62aa862',
#   'e45505c5-2067-46bc-ab7f-1884d8367b63',
#   'e481d991-7cb4-440e-bf3b-da69e89d5319',
#   'e5b38bfe-3652-48d7-bbb9-b3ede5ddfb89',
#   'e67078c6-d395-44d3-a9d0-accd742dcdfa',
#   'e6c8b713-d05c-4ed7-a84d-fdef20c3e913',
#   'ec5e361c-e393-4643-b095-411c547333ab',
#   'ecc7509f-bb2c-4c1d-8fd5-3e1da8bf82b3',
#   'ed229a20-e54d-47eb-8637-140d553bcd10',
#   'f03adee8-225f-4db7-a229-c9474fbed56a',
#   'f0b0f243-9f9e-40a8-af80-c07d420e799b',
#   'f21c2abf-5038-4b58-a66d-e528bc97b624',
#   'f23d2518-c8c9-44e4-9c09-38331b3f3e14',
#   'f7edaf58-37d0-4db5-be48-30e83dea6e74',
#   'fb63ef7f-faa3-4bb2-b49b-bdb5c24b2903',
#   'fb74c0a3-a651-429a-a949-85dd66d58b1b',
#   'fc698981-62d0-47aa-9447-0c596d130d11',
#   'fd42b8dd-f5cb-4d3d-a3ea-7ccc2e4bec46',
#   'fdfa3e99-71a8-4466-857d-f20471d83c95'],
#  'embeddings': None,
#  'metadatas': [{'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-Code-of-Conduct-Policy-Vietnamese-version.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Travel Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Quality Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Annual Trip Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam 1on1 Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Leave Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Performance Evaluation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Hybrid Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Fresher Training Period Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Remote Work Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Recruitment Referral Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Human Resources Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Office Access Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Human Resources Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Foundation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Domestic Travel Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Employee ICT Policy and Procedure.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Quality Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Probation Period Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam New Team Kick Off Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Passing-away Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Fresher Training Period Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Escalation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Hybrid Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Team Building Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Feedback Sharing Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Salary Exchange Rate Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Confidentiality Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Project Release Celebration Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Quality Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Time Reporting Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Anti-Corruption and Anti-Bribery Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Performance Evaluation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Gifts Frequency Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK_Technologies_Vietnam_Travel_Allowances_Schedule.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Salary Exchange Rate Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Employee ICT Policy and Procedure.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Escalation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Relaxation Areas Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Overtime Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Personal Data Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Employee ICT Policy and Procedure.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Annual Trip Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Travel Allowance Schedule D.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Recruitment Referral Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Trade Union Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Export Control Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Accidental Death & Disability and Health Insurance Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Work From Home Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Export Control Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Team Building Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Accidental Death & Disability and Health Insurance Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Personal Data Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-13th-month-Bonus-Regulation_A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam TOIL Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-13th-month-Bonus-Regulation_A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Tuition Reimbursement Policy B.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Family Day Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Work From Home Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Passing-away Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Office Access Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Relaxation Areas Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Office Transfer Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Work From Home Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-13th-month-Bonus-Regulation_A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Probation Period Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Overtime Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-Code-of-Conduct-Policy-Vietnamese-version.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-International-Travel-Policy-D.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Annual Trip Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Visitor Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Internal Trainer Development Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-Office-Transfer-Policy_B.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-International-Travel-Policy-D.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Export Control Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Remote Work Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-Office-Transfer-Policy_B.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Personal Data Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Feedback Sharing Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Personal Data Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Travel Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Family Day Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Hybrid Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Internal Trainer Development Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Working Hours Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Visitor Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Health & Safety Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Working Hours Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam 1on1 Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Disciplinary Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Foundation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam International Travel Policy C.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Employee ICT Policy and Procedure.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Health & Safety Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam International Travel Policy C.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Time Reporting Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Anti-Corruption and Anti-Bribery Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Escalation Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Confidentiality Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Internal Trainer Development Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK_Technologies_Vietnam_Travel_Allowances_Schedule.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Human Resources Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Anti-Corruption and Anti-Bribery Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Personal Data Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Code of Conduct Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-Office-Transfer-Policy_B.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Travel Allowance Schedule D.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam TOIL Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Domestic Travel Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Salary Exchange Rate Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Gifts Frequency Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK-Technologies-Vietnam-International-Travel-Policy-D.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies ICT Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Fresher Training Period Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK_Technologies_Vietnam_On-Call_Support_Service_Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Environmental Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Trade Union Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Project Release Celebration Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Code of Conduct Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam International Travel Policy C.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam New Team Kick Off Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Office Access Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Leave Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Tuition Reimbursement Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK_Technologies_Vietnam_On-Call_Support_Service_Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Employee ICT Policy and Procedure.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Recruitment Referral Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Office Transfer Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Time Reporting Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Disciplinary Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Health & Safety Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Internal Trainer Development Policy A.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Vietnam Environmental Policy.pdf'},
#   {'page': 0,
#    'source': '/Users/tienvinhnguyen/Projects/ai-chatbot/main-source/.DOCS/DEK Technologies Human Resources Policy.pdf'}],
#  'documents': ['Prepared: phuong.th.nguyen  Document no: DEK-21:0047  \nApproved: Support Function   Revision: A \n Security class: Internal   Date:  04/07/2021  \n      Document Type: Policy   \n \n \nPage 1 of 12 \nThis document is UNCONTROLLED when printed  \n \nBộ Quy T ắc Ứng X ử - Công Ty DEK Technologies Vi ệt Nam  \n1. Mục đích  \nBộ Quy Tắc Ứng Xử này kh ẳng đ ịnh cam k ết của Công Ty DEK Technologies Vi ệt Nam và toàn th ể \nnhân  viên công ty  trong vi ệc duy trì và phát huy các giá tr ị sau: \n• Chính tr ực trong t ất cả các hoạt động và đưa ra quyết định.  \no Chính tr ực trong  hoạt động kinh doanh.  \no Chính tr ực trong cách hành  xử: giữa công ty v ới nhân viên, gi ữa đồng nghi ệp với \nnhau.  \no Chính tr ực trong cách  xử lý các thông tin liên quan  \n• Công b ằng – tạo dựng văn hóa làm vi ệc công b ằng, tuân th ủ các quy đ ịnh c ủa công ty, tôn \ntrọng lẫn nhau , tìm các gi ải pháp  cân b ằng lợi ích gi ữa các bên .  \n• Trở thành m ột tổ chức có trách nhi ệm với xã h ội [1] [2] \n2. Ngày hi ệu lực',
#   'Prepared: Support Function Document no: DEK-14:0115  \nApproved: Daniel Tedesco Revision: B \nSecurity Class: Internal  Date: 29/10/2020 \n Document Type: Policy \n \n \n \nPage 1 of 4 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Travel Policy \n1 Purpose \nThe opportunity to travel is a positive benefit for a member, and to ensure that it remains mutually \nbeneficial to the member and DEK Technologies Vietnam, this document is intended to clearly define \nthe expectations and constraints for travel. \n2 Effective Date \nThis version of the policy is effective from the 1st of August 2020. \n3 Principles \nThe length of time it takes to recover the cost of a business trip for a DEK Technologies Vietnam \nmember is a substantially long time. \nWork travel and decisions will be at lowest cost to the company and customer, commensurate with \nmaintaining a reasonable standard of comfort and convenience.',
#   'DEK T ECHNOLOGIES  Internal  \nPOLICY   \n1 (1) \nPrepared (also subject responsible if other)  No. \nDEK/Robert Bunn  DEK-06:0033  \nApproved  Checked  Date  Rev Reference  \nDEK/Robert Bunn   2018 -04-17 E  \n \nThis document is uncontrolled when printed (unless signed)  \n  \n \nDEK Technologies Quality Policy  \n \nContext  DEK Technologies provides services that consistently satisfy the needs and \nexpectations of our customers, in order to generate sustained, profitable \ngrowth.  \nPurpose  We mai ntain a structured processes view of our company operations, compliant \nto the ISO9001:20 15 International Quality Standard and implemented as our DEK \nQuality Management System (QMS).  \nBenefits  • Consistency in the way our business activities are conducted.  \n• Describing business processes in writing help to highlight areas for \nimprovement  \n• Customers have greater confidence in businesses that apply a quality \nmanagement system. In fact,  it is a mandatory requirement by some of DEK’s',
#   'All members are encouraged to attend the annual trip; however, it is not a mandatory event. \nSome events at the annual trip are mandatory, while others are voluntary to participate in. Members \nmust be involved in all mandatory events. If a member is missing any mandatory event during the trip \nwithout prior approval in writing, that member is responsible for paying all their related costs which \ncannot be recovered. \nThe annual trip will be for three days, two of which will be on the weekend and one on a \nweekday/working-day. \nFor members who do not attend the annual trip, the office will remain open on the weekday/working-\nday of the annual trip, to allow them to work on that day. If a member not attending wishes to take the \nwork day off, leave must be used. \nA member who is registered to attend but then does not attend or participate, is responsible for paying \nall their related costs which cannot be recovered.',
#   'Prepared: Support Function  Document no: DEK-23:0046   \nApproved: Daniel Tedesco  Revision: A \nSecurity Class: Internal   Date: 01/07/2023  \n Document Type: Policy  \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam 1on1 Policy  \n1 Purpose  \nTo give members an opportunity to share any improvement feedback to the team, the area, and the \ncompany. The 1on1 session  is also for members to share the career interest that they want to develop \nin a short and long -term period.  \n2 Effective Date  \nThis versio n of the policy is effective from the 1st July 2023  \n3 Principles   \nDEK Technologies  Vietnam want s to build a good working environment where  members feel that they \nbelong to the organization and grow in the way that they want.  \nMembers are always encouraged to  give their feedback. DEK Technologies Vietnam actively listen s to \nall feedback in a collaborative way and take s corresponding action plan depend ing on the feedback \nitself .',
#   'Prepared: Support Function  Document no: DEK-14:0125   \nApproved: Daniel Tedesco  Revision: D \nSecurity Class: Internal   Date: 22/9/2022  \n Document Type: Policy  \n \n \n \nPage 1 of 5 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Leave  Polic y \n1 Purpose  \nTo clearly define how all forms of leave can be used within DEK Technologies Vietnam while still \nensuring that the customers’  expectations are always exceeded.  \nDEK Technologies Vietnam encourages  a good work life balance.  \n2 Effective Date  \nThis version of the policy is effective from the 22nd September 2022 . \n3 Principles  \nThe valid leave types at DEK Technologies Vietnam are:  \n• Annual Leave  \n• TOIL Leave  \n• Public Holidays  \n• Bereavement Leave  \n• Parental L eave  \n• Maternity Leave  \n• Wedding Leave  \n• Sick Leave  \n• Menstruation Period Leave  \n• Leave without Pay  \nDeliveries take higher priority than leave, and leave can be changed or cancelled without any problem.',
#   'Vietnam. Please refer to here in the DEK Quality Management System (QMS).  \nThe other DEK offices and/or the customer can be asked for the input of a member’s performance when \nrequired. \nAll PE information collected will not be shared with the members who are evaluated. Therefore, \nmembers should feel free to give open and honest feedback. \nDEK Coaches and LMs are to evaluate each member’s performance fairly. \nThe output of the PE will not be shared with members. However, if members want to get feedback for \nself-improvement, they should register for Feedback Sharing [1]. \nThe output of the PE is only one of many inputs into the salary review. \nPromotion is considered at the end of each year. For further information, please refer to Promotional \nPath document [2].',
#   'If members  get a fever or a contagious disease  or unexpected health incidents , they should inform \nteams, LMs, DH, HR so that additional WFH days can be considered .  \nVideos must  be used in meeting s to ensure clear communication and collaboration.  \nHere are a few tips to help members  WFH more effectively:',
#   'Prepared: Support Function  Document no: DEK-14:0016   \nApproved: Daniel Tedesco  Revision: C \nSecurity Class: Internal   Date: 05/05/202 1 \n Document Type: Policy  \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Fresher Training Period  Policy  \n1. Purpose  \nTo clearly define the expectations and  behaviors  of members who are in  their 3-month Fresher T raining Period . \n2. Effective Date  \nThis version of the policy is effective from the 1st date of January  2021. \n3. Principles  \nThe Fresher Training Period is a program that allows the Fresher:  \n• to smoothly integrate into the company’s culture and environment  \n• to gain technical skills  and soft skills to adapt to the real project of the ir team  \n• to have  a chance to evaluate if the  company  is a good match for them  \n \nThe Fresher Training Period is a program that allows DEK Technologies Vietnam:',
#   'Prepared: Support Function s Document no: DEK-23:0027   \nApproved: Daniel Tedesco  Revision: A \nSecurity Class: Internal   Date: 01/05/2023  \n Document Type: Policy  \n \n \n \nPage 1 of 3 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Remote Work  Polic y \n1 Purpose  \nTo clearly define  the policy and benefits  of remote workers.  \n2 Effective Date  \nThis version of the policy is effective from 1st May, 2023.  \n3 Principles  \nDEK Technologies  Vietnam  trusts all members to work at a sustainable pace . \nThe Remote Work policy is intended to allow flexibility and to make DEK Technologies Vietnam an \nattractive workplace.  \nThere are different benefits between office and remote members. For m ore information , please refer to \nthis link. Overseas travel is not applied as a priority for remote members unless there is a special \nrequest from the customer.  \nMembers must sign the Minutes of Confirmation and Commitment  before becoming official remote \nmembers.',
#   'new talent to DEK Technologies Vietnam .  \n4 Policy  \nAll members  are eligible to participate in the RRBP except for  the Recruitment members of the Human \nResource Department  (HR) .  \nFor a member to receive the referral bonus, the candidate they recom mend cannot be:  \n• a former employee  within 1 year , \n• a past contractor or agency employee previously used by DEK Technologies Vietnam,  \n• someone who DEK Technologies Vietnam has already received the details of in the previous 1 year;  \nand the candidate must pass the probation or training period and become a fulltime member.  \nAll referrals must be received by email.  \nMembers  are eligible for re wards within 12 months from the date the referral email is received even if a \ncandidate is interviewed at a later time or gets hired for another position.  \nThere is no cap on the number of referrals a member  can make. All referral bonuses  will be paid \naccordingly .',
#   'DEK TECHNOLOGIES  Internal \nPOLICY  \n1 (1) \nPrepared (also subject responsible if other) No. \nDEK/Robert Bunn DEK-12:0021 \nApproved Checked Date Rev Reference \nDEK/Robert Bunn  2012-03-29 A  \n \nThis document is uncontrolled when printed (unless signed) \n  \n \nDEK Technologies Human Resources Policy \n \nContext  DEK Technologies is first and foremost a consultanc y company. Our people are our \nlifeblood. All aspects of HR need to run smoothly a nd unambiguously in order for DEK \nto prosper. \nPurpose  • We maintain a structured process view of our HR ope rations, in order to have \nclarity on:- \no The nature of the organization \no What employees should expect from the organization,  and what the \norganization expects of them \no How detailed policies and procedures work \no What is acceptable and unacceptable behaviour \no The consequences of unacceptable behaviour \n• To demonstrate compliance with legislation/regulati ons, ethics, diversity, and \ncorporate governance requirements.',
#   'Prepared: Support Function Document no: DEK-14:0119  \nApproved: Daniel Tedesco Revision: B \nSecurity Class: Internal  Date: 15/07/2020 \n Document Type: Policy \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Office Access Policy \n1 Purpose \nTo clearly define the expectations and constraints with in which a member can access and use the \noffice. \nDEK Technologies Vietnam encourages healthy members to be able to freely access the office.  \n2 Effective Date \nThis version of the policy is effective from the 1st of August 2020. \n3 Principles \nSecurity of the DEK Technologies Vietnam office is important and must be taken seriously. \nEach member is responsible to ensure the security of the DEK Technologies Vietnam office. \nThe DEK Technologies Vietnam office is available only to current healthy DEK Technologies Vietnam \nmembers without supervision or pre-approval 24/7. \nEach member must treat the office and the equipment with respect.',
#   'o The consequences of unacceptable behaviour \n• To demonstrate compliance with legislation/regulati ons, ethics, diversity, and \ncorporate governance requirements. \n• To build and support the desired organizational cul ture, and foster an efficient   \nwork environment. \nBenefits  • Satisfied employees means higher retention, greater  efficiency and less conflict. \n• In the event of legal proceedings, DEK has necessar y records in place to defend \nit’s position. \n• DEK becomes known as an employer of choice within t he industry. \n• Staff are empowered to work within their areas of r esponsibility, which in turns \nallows DEK to have a relatively flat organization, and therefore low overheads. \nPrinciples  • HR activities are conducted fairly, with transparen cy, and without discrimination. \n• A balance between business drivers, legal & moral s tanding and the “employee \nwanted position” is maintained. \n• All aspects of the employment cycle are documented in the QMS: Recruitment,',
#   'sustainable, fair and equitable solutions that address the causes and symptoms of the poor and \nunderprivileged. \nThe DEK Technologies Vietnam Foundation Committee was created to give DEK Technologies Vietnam \nmembers the opportunity to actively make positive contributions to the Vietnamese society (e.g. \nsupporting ethnic minority children and families, supplying necessities to the homeless, etc.) as part of \nthe global DEK Technologies Foundation initiative. \nDEK Technologies Vietnam members are encouraged to raise ideas and causes to support. \n4 Policy \nThe DEK Technologies Vietnam Foundation Committee must have the following minimum roles formally \nfilled to be active: \n\uf0b7 Chairperson \n\uf0b7 Financial Officer \n\uf0b7 Secretary \nAll positions in the DEK Technologies Vietnam Foundation Committee are volunteer positions. \nThe DEK Technologies Vietnam Foundation Committee will create and present a yearly plan to all DEK \nTechnologies Vietnam members and the DEK Technologies Foundation.',
#   'Travel should be organiz ed and planned to minimize the number of non -working days.  \n4 Policy  \nNo one can be forced to travel; all travel must be voluntarily accepted. There is no negative \nconsequence for not travelling.  \nAny and all claims must be made with a receipt. No claims will be honored without receipts.  \nDEK Technologies Vietnam  provides business trip facilities as follo ws: \n• Transportation:  \nDEK Technologies Vietnam organizes  an appropriate means of transportation depending on business \nneeds.  \nDEK Technologies Vietnam covers the reasonable transport fees (taxi, car, bus, ferry, boat, toll fees) \nfrom  the actual accommodation to departure and from arrival to the actual accommodation,  where DEK \nTechnologies Vietnam Office is located (e.g. Ho Chi Minh city, Hanoi city, etc.). Members must provide \nthe actual financial invoices.  \nThe covered maximum transport  fee is 500.00VND/way.',
#   '3.2 IMPLEMENTATION  ................................ ................................ ................................ ...........  12 \n4 AUDIT  ................................ ................................ ................................ ................................ ...... 12 \n5 REVISION INFORMATION  ................................ ................................ ................................ .......  13',
#   'improvement  \n• Customers have greater confidence in businesses that apply a quality \nmanagement system. In fact,  it is a mandatory requirement by some of DEK’s \ncustomers.  \nPrinciples  The corner stones for DEK’s ongoing success are: - \n• Deployment of highly professional, motivated and competent staff.  \n• Thorough understanding of customer needs and forming long term \nrelationships.  \n• Continual  improvement in all aspects of the business, to support ongoing  \ngrowth.  \n• Supportive management that steers the business in a responsible way.   \nResponsibilities          \n    • The DEK Technologies Quality Manager will ensure that the QMS is kept up \nto date.  \n• Senior Management at DEK are  responsible to ensure that all staf f are aware \nof, participate in, and follow the intent of the QMS.  \n• DEK employees must be fully aware of the contents of the QMS and  be able  \nto reach it via the below link and  notify management of any shortcomings.',
#   'higher level; \n\uf0b7 Must not exceed 30 days for jobs that require professional and technical qualifications of intermediate \nvocational level, professional secondary level, or for technical workers and skilled employees. \nThe Probation Period is a program that allows the new member: \n\uf0b7 to smoothly integrate into the company’s culture and environment \n\uf0b7 to gain technical skills and soft skills to adapt to the real project of their team  \n\uf0b7 to have a chance to evaluate if the company is a good match for them \nThe Probation Period is a program that allows DEK Technologies Vietnam: \n\uf0b7 to provide training and mentoring to build the required technical skills and soft skills \n\uf0b7 to find members who are eager to learn, especially new technology \n\uf0b7 to find compatible and long-term members to join the company \n\uf0b7 to orientate members and help choose the best direction for them \n\uf0b7 to support members to contribute to the success of their team and the company',
#   '• Lunch  \n• Dinner  \n• Bowling  \n• Karaoke  \n• Night at the cinema  \n• Escape room  \n• etc. \n4 Policy  \nThe budget for  a new team kick off is 300 .000VND  per person . \nThe budget is only applied if a ll team member s attend  the kick off activity , i.e., if you have a five -person \nteam but only four people join the activity , the budget is not approved.  \nThe new team kick off activity must be organized within a month from the beginning date the new team \nis formed, if not the budget is no longer approved.',
#   'Prepared: Support Function s Document no:  DEK-23:0065     \nApproved: Daniel Tedesco  Revision: A \nSecurity Class: Internal   Date: 01/09/202 3 \n Document Type: Policy  \n \n \nPage 1 of 3 This document is UNCONTROLLED when printed  Passing -away Policy  \n1 Purpose  \nTo honor  the memories and the contribution of our past  member s and to share condolences with their  family . \nThis is also t o guide their family  with the  necessary  information for the insurance claim  process . \n2 Effective Date  \nThis version of the policy is effective from 1st September 2023 . \n3 Principles  \nTo ensure the family of the past member receives  full entitlements . \n4 Policy  \na. The condolences support : \n- From the company:  \n• Condolences amount:  10.000.000 VND   \n•  Flower: 1.000.000 VND  \n- From Trade Union:  \n• Condolences amount:  2.000.000 VND   \n•  Flower:  700.000 VND  \nb. The members to visit the past member’s family  as early as we can but no later than th e first 3 days :',
#   '• to have  a chance to evaluate if the  company  is a good match for them  \n \nThe Fresher Training Period is a program that allows DEK Technologies Vietnam:  \n• to provide training and mentoring to build the required technical skills and soft skills  \n• to find Freshers  who are eager to learn, especially new technology  \n• to find compatible and long -term members to join the company  \n• to orientate Freshers  and help choose the best  direction for them  \n• to support Freshers  to contribute to the success of their team and the company  \n4. Policies  \nAfter the Fresher Training Period is successfully completed, Freshers who choose to sign a labour contract \nare committing to work with DEK Technologies Vietnam for a 1 -year period.  The commencement of the 1 -\nyear  commitment period is counted from the day o f signing the labour contract.  \nIf the member breaks the commitment period, they are required to reimburse the Training Fee . Training Fee',
#   'Prepared: Support Function Document no: DEK-19:0162  \nApproved: Daniel Tedesco Revision: B \nSecurity Class: Internal  Date: 14/07/2020 \n Document Type: Policy \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Escalation Policy \n1 Purpose \nTo clearly define the expectations of the internal and external escalation paths to be used within DEK \nTechnologies Vietnam. \n2 Effective Date \nThis version of the policy is effective from the 1st of August 2020. \n3 Principles \nAs a company we can only solve issues and make improvements if we are aware of the problems or \nideas for improvements. \nDEK Technologies Vietnam is not a hierarchal company, and every member is welcomed to speak \ndirectly to anyone in any position of the company. For example, everyone is welcomed to raise any of \ntheir concerns or ideas directly to the General Director. \nDEK Technologies Vietnam strives to understand different perspectives and find win-win solutions and',
#   'Prepared: Support Function  Document no: DEK-23:0024   \nApproved: Daniel Tedesco  Revision: A \nSecurity Class: Internal   Date: 1 2/4/2023  \n Document Type: Policy  \n \n \n \nPage 1 of 3 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Hybrid Working  Polic y \n1 Purpose  \nTo clearly define the expectations and constraints  when  applying the Hybrid Working  (Hybrid)  model : \n• To ensure t he customers’ expectations are always exceeded.  \n• To give our members a flexible working from home (WFH) model  \n• To make DEK Technologies Vietnam an attractive and modern workplace.  \n2 Effective Date  \nThis version of the policy is effective from the 1st of May 2023 . \n3 Principles  \nThe Hybrid policy is only app licable for members:  \n• If agreed by the customer  \n• And/or depending on the type of work.  \nThe commitment to your  members and customers comes first and must be  prioritized . Some examples:  \n• starting a new project  \n• mentoring junior members',
# ...
#   'year  commitment period is counted from the day o f signing the labour contract.  \nIf the member breaks the commitment period, they are required to reimburse the Training Fee . Training Fee  \nmeans all fee s, costs and expenses incurred or paid by DEK Technologies Vietnam for the Training, which \ninclude s but is not limited to training fee : fees paid for trainers, training materials, classes, machinery, \nequipment and practical materials, etc., the Financial Support , and other cost.',
#   'Members  are actively responsible  and accountable  for solving customer’ s problems in the fastest  way. \nThere are two types of comp ensation provided to members  who are on 24/7 support : \n• On-call allowance  \no This allowance is to compensate for the 24/7 availability. This allowance is paid \nregardless if a call is received or not. The allowance is calculated on a daily basis and \npaid monthly.  \n• Actual  support  hours  payment (outside normal working  hour s) \no This payment is to compensate  for any support hours worked  outside normal working  \nhour s. \nNo members will be forced to work on OSS.  \nThe members who participate in OSS must have:  \n• the required set of technical skills and competence that cover s the  customer  competence areas \n(product knowledge), infrastructure and network.  \n• adequate English and communication skills to directly interact with the customer .',
#   'and services in Vietnam. \nWe commit to: \n\uf0b7 prevent pollution and a continual improvement regime \n\uf0b7 comply with relevant regulations of laws and other requirements related to the environment \n\uf0b7 establish a framework to set environmental goals and indexes \n\uf0b7 popularize environmental awareness to all members of the company \n\uf0b7 improve public awareness \nThe DEK Technologies Vietnam Environmental Ambassador Team is responsible for championing the \nprotection of the environment in Vietnam, and challenging both members and the company to do \nmore.',
#   'Prepared: Trade Union Document no: DEK-14:0127  \nApproved: Daniel Tedesco Revision: B \nSecurity Class: Internal  Date: 30/07/2020 \n Document Type: Policy \n \n \n \nPage 1 of 3 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Trade Union Policy \n1 Purpose \nTo clarify the rights and responsibilities of the DEK Technologies Vietnam Trade Union Committee and \nMembers. \n2 Effective Date \nThis version of the policy is effective from the 1st of July 2020. \n3 Principles \nThe Trade Union (TU) was established to: \n\uf0b7 Represent members in order to persuade, negotiate with DEK Technologies Vietnam about \nmembers’ benefits in case they need help \n\uf0b7 Build a good working environment for members (e.g. organize sports clubs, TU events, provide \nsupport in important personal events or issues, maintain entertainment equipment, etc.) \nThe Trade Union (TU) committee is responsible for managing and executing the activities and \nresponsibilities of the TU. \n4 Policy',
#   'Prepared: Support  Functions  Document no: DEK-23:0064   \nApproved: Daniel Tedesco  Revision: A \nSecurity Class: Internal   Date:  01/10/202 3 \n Document Type: Policy  \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Project Release  Celebration (P RC) Polic y \n1 Purpose  \nTo recognize the effort and contribution from teams and celebrate the achievements of the area.  \n2 Effective Date  \nThis version of the policy is effective from the 1st of Oc tober , 2023.  \n3 Principles  \nThe PRC budget is intended to allow areas (e.g., SBG, Seeing Machines, IMS Tools, HR, Finance, ICT, etc.) \nto celebrate achievements each quarter  at the office.  \nThe event is not allowed to be organized  outside the office.  \nSome activities recommended for PRC are: \n• Lunch  \n• Dinner  \n4 Policy  \nThe budget for the PRC is 100.000 VND per member  per quarter.  \nThe budget is only applied for registered  members , i.e. if the area has 30 members  but only 20 members',
#   '3 Principles  \nWe believe in  and follow (even when no one is watching) : \n• doing the right thing , in the right way, and for the right reasons   \n• keeping  our commitments  \nEvery member  is obliged to personally live up to the  high ethical standards we have set for ourselves in \nthe Code of  Conduct, as well as to help prevent, detect, and respond to  violations of the Code of \nConduct . \nMembers  at all levels  must provide guidance and support so their  colleagues  make the right decisions \nand play fair.  \nIt is the responsibility of every member  to unde rstand and follow the  Code of Conduct . \nAny member who reasonably suspects that a violation of the Code of Conduct  has occurred or is likely \nto occur , must  report their concerns immediately . There are several ways to do this – including \nanonymously. Importantly, DEK Technologies Vietnam will never  retaliate against any member  who \nreports such a suspicion.',
#   'The terms of the Business trip travel category, such as daily allowance etc., will be determined by the \ncustomer.  \n    \n3.2  Office Exchange Program travel  \nOffice Exchange Program travel category is for when the trip is:',
#   'Prepared: Support Function  Document no: DEK-23:0055    \nApproved: Daniel Tedesco  Revision: A \nSecurity Class: Internal   Date: 01/09/202 3 \n Document Type: Policy  \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam New Team Kick Off Polic y \n1 Purpose  \nTo give members a chance to get  to know each other when a new team  is formed  in the current  or new \nassignment.  \n2 Effective Date  \nThis version of the policy is effective from the 1st of September  2023. \n3 Principles  \nIt is important to know about our members in a new team  in the current or new assignment.   \nThese cases below will not be valid:  \n• Team split  in the same assignment.  \n• Team names  change with current members.  \nSome recommended team activities are:  \n• Lunch  \n• Dinner  \n• Bowling  \n• Karaoke  \n• Night at the cinema  \n• Escape room  \n• etc. \n4 Policy  \nThe budget for  a new team kick off is 300 .000VND  per person .',
#   'Each member is responsible for his or her actions while at the office and accepts the consequences of \ntheir actions. \nNo visitor can access the building without signing in with the guards. \nVisitors must park their bikes outside the front of the office.',
#   '• Wedding Leave  \n• Sick Leave  \n• Menstruation Period Leave  \n• Leave without Pay  \nDeliveries take higher priority than leave, and leave can be changed or cancelled without any problem.  \nThe number of Annual leave days available to staff each calendar year follows the labour laws of \nVietnam.  \nWhen taking leave in multiple of 4 hours, Annual Leave must be used before any TOIL.  \nThe policy is designed to encourage a good and healthy work life balance.',
#   'Prepared: Support Functions  Document no: DEK-23:0030   \nApproved: Daniel Tedesco  Revision: A  \nSecurity Class: Internal  Date: 01/05/2023  \n Document Type: Policy  \n \n   \nPage 1 of 7 This document is UNCONTROLLED when printed . DEK TUITION  REIMBURSEMENT  POLICY  \nContents   \n1. What is tuition reimbursement?  \n2. Purpose   \n3. Important definitions  \n4. Tuition reimbursement process for non -advanced Degrees  (Degree Programs, \nCertifications and Professional Memberships)   \na. Reimbursement provisions   \nb. General eligibility guidelines for tuition reimbursement   \nc. Certificates / Course guidelines  \nd. Approval and reimbursement process/checklist   \n5. Tuition reimbursement process for Advanced Degrees  (master’s, MBA, and Ph.D.)  \na. Reimbursement provisions   \nb. General eligibility guidelines for tuition reimbursement   \nc. Approval and reimbursement process/checklist    \n6. Frequent asked question',
#   'Prepared: Support Function  Document no: DEK-20:0114   \nApproved: Daniel Tedesco  Revision: B \nSecurity Class: Internal   Date: 11/01/2021 \n Document Type : Policy  \n \n \n \nPage 1 of 3 This document is UNCONTROLLED when printed  DEK Technologies Vietnam On-call Support  Service  Policy  \n1 Purpose  \nThis policy defines the  responsibilities and compensation for On-call Support  Service  (OSS) . \n2 Effective Date  \nThis version of the policy is effective from the 1st of January  2021. \n3 Principles  \nOSS refers to the service that provides 24 /7 support for customers . This means that members must be \nable to answer a call from the customer at any time during a 24 -hour period. Once a call is received the \nmember must respond according to the Service Level Agreement  (SLA)  defined by the customer.  \nMembers  are actively responsible  and accountable  for solving customer’ s problems in the fastest  way.',
#   '1.5 BACKUP AND REVISION CONTROL  ................................ ................................ ...................  10 \n1.6 BREACH OF REGULATION  ................................ ................................ ................................ . 10 \n2 ICT PROCEDURES FOR USERS  ................................ ................................ ................................ . 10 \n2.1 NEW EQUIPMENT  ................................ ................................ ................................ ............  10 \n2.2 DECOMMISSIONING EQUIPMENT  ................................ ................................ ...................  11 \n2.3 NEW USERS  ................................ ................................ ................................ ......................  11 \n2.4 USER ACCOUNTS  ................................ ................................ ................................ ..............  11',
#   'candidate is interviewed at a later time or gets hired for another position.  \nThere is no cap on the number of referrals a member  can make. All referral bonuses  will be paid \naccordingly . \nIf multiple referrals for  the same candidate are received , the first emailed referral will be eligible for the \nreferral bonus if applicable .',
#   'Once someone qualifies to be registered as part of the office transfer program, it may take time to \nexecute the actual move, and we ask for the patience and understanding of the member. \n4 Policy \nTo qualify to register to be part of the office transfer program, the member themselves must meet four \nmain criteria: \n\uf0b7 Loyalty \no Needs to be a current member of DEK Technologies Vietnam and has worked for the \ncompany for a minimum of 5 years \n\uf0b7 Attitude \no Has a proven history of being a responsible team player who has had a positive overall \ninfluence on his colleagues and the business \n\uf0b7 Performance \no Has a proven history of high performance and contribution \n\uf0b7 English \no Able to communicate smoothly in English. This involves all the four skills of reading, \nwriting, speaking and listening',
#   'Prepared: Support Function Document no: DEK-14:0120  \nApproved: Daniel Tedesco Revision: B \nSecurity Class: Internal  Date: 28/10/2020 \n Document Type: Policy \n \n \n \nPage 1 of 2 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Time Reporting Policy \n1 Purpose \nTo clearly define the expectation on how hours should be accurately and honestly reported. \n2 Effective Date \nThis version of the policy is effective from the 1st of August 2020. \n3 Principles \nAccurate and honest time reporting is extremely important. \nDishonest time reporting is the equivalent of stealing. \nWeekly submission of timesheets helps ensure their accuracy and allows faster processing of salaries. \nNon project related or connected activities should not be reported against the project. \n4 Policy \nEvery member must submit their timesheets either at the end of the last day of the week, or at the \nbeginning of the first day of the week.',
#   'case and call witnesses to support their case, as appropriate. \n\uf0b7 Be accompanied to disciplinary meetings by a witness. \n\uf0b7 Be normally not dismissed for a first offence, other than gross misconduct. \n\uf0b7 Be informed and encouraged to use the right of appeal.  \nNo disciplinary action will be taken against a member unless the case has been investigated or evidence \nis available.',
#   'might be affected by our operations.  \n4 Policy \nMembers will be provided with the equipment, information and training as is necessary to implement the \npolicy and achieve the stated objective. \nOnly authorized suppliers and members are allowed to access dangerous areas such as the power station, \nelectricity hub, power generator, elevator machine room, air-conditioning units, building riser, server \nrooms, and water station. The member and supplier’s staff must have a certified qualification to access \nsuch areas. \nSmoking is prohibited inside the office, including basements, balconies on level 5 & 7 and the roof top. \nMembers are not allowed to access the billboard structure and the roof top. \nMembers are not allowed to climb on the handrails of the balconies on level 5 & 7. \nTo maintain a hygienic office fulltime cleaning services must be in place, including regular pest control \nmeasures. Meals should not be consumed in the working area.',
#   '• or confirmation from their direct manager/ leader;  \n• or formal training (recognized institution certificate, university degrees)  \n3.2.2.  Delivery skill  \nThe trainer’s delivery skill, also known as training delivery and facil itation skill is the ability to help individuals \nimprove performance at work by learning new skills and knowledge. The trainer serves as a catalyst for \nlearning by understanding the learner’s needs, creating the right environment for learning, building rap port \nwith participants, and using the appropriate delivery options and media to make learning engaging, effective, \nrelevant, and applicable. This ability is demonstrated by:',
#   'Prepared: Support Function Document no: DEK-20:0091  \nApproved: Daniel Tedesco Revision: A \nSecurity Class: Internal  Date: 03/08/2020 \n Document Type: Policy \n \n \n \nPage 1 of 3 This document is UNCONTROLLED when printed  DEK Technologies Vietnam Environmental Policy \n1 Purpose \nTo define the DEK Technologies Vietnam environmental guidelines, responsibility and activities.  \nTo clarify the rights and responsibilities of the DEK Technologies Vietnam Environmental Ambassador \nTeam. \nFor the DEK Technologies global environmental policy please refer to the DEK Environmental Policy [1] \ndocument. \n2 Effective Date \nThis version of the policy is effective from the 1st of August 2020. \n3 Principles \nAs a company we want to reduce the environmental impact of our organization’s activities, products \nand services in Vietnam. \nWe commit to: \n\uf0b7 prevent pollution and a continual improvement regime \n\uf0b7 comply with relevant regulations of laws and other requirements related to the environment',
#   'necessary to comply with county specific legislatio n or situations. \nRelated Documents  Employee Values and Practices Manual, DEK -05 :00 76  \nRelated Links  HR  information can be found spread throughout  http://dekdoc.dektech.internal/ , \nmore specifically the STAFF RELATED section.'],
#  'uris': None,
#  'data': None}

# %%
metadatas = docs["metadatas"]

# %%
files = [metadata['source'].split('/')[-1] for metadata in metadatas]
files
# Out:
# ['DEK-Technologies-Vietnam-Code-of-Conduct-Policy-Vietnamese-version.pdf',
#  'DEK Technologies Vietnam Travel Policy.pdf',
#  'DEK Technologies Quality Policy.pdf',
#  'DEK Technologies Vietnam Annual Trip Policy.pdf',
#  'DEK Technologies Vietnam 1on1 Policy A.pdf',
#  'DEK Technologies Vietnam Leave Policy.pdf',
#  'DEK Technologies Vietnam Performance Evaluation Policy.pdf',
#  'DEK Technologies Vietnam Hybrid Policy A.pdf',
#  'DEK Technologies Vietnam Fresher Training Period Policy.pdf',
#  'DEK Technologies Vietnam Remote Work Policy A.pdf',
#  'DEK Technologies Vietnam Recruitment Referral Policy.pdf',
#  'DEK Technologies Human Resources Policy.pdf',
#  'DEK Technologies Vietnam Office Access Policy.pdf',
#  'DEK Technologies Human Resources Policy.pdf',
#  'DEK Technologies Vietnam Foundation Policy.pdf',
#  'DEK Technologies Vietnam Domestic Travel Policy A.pdf',
#  'DEK Technologies Employee ICT Policy and Procedure.pdf',
#  'DEK Technologies Quality Policy.pdf',
#  'DEK Technologies Vietnam Probation Period Policy.pdf',
#  'DEK Technologies Vietnam New Team Kick Off Policy A.pdf',
#  'DEK Technologies Vietnam Passing-away Policy.pdf',
#  'DEK Technologies Vietnam Fresher Training Period Policy.pdf',
#  'DEK Technologies Vietnam Escalation Policy.pdf',
#  'DEK Technologies Vietnam Hybrid Policy A.pdf',
#  'DEK Technologies Vietnam Team Building Policy.pdf',
#  'DEK Technologies Vietnam Feedback Sharing Policy.pdf',
#  'DEK Technologies Vietnam Salary Exchange Rate Policy.pdf',
#  'DEK Technologies Vietnam Confidentiality Policy.pdf',
#  'DEK Technologies ICT Policy.pdf',
#  'DEK Technologies Vietnam Project Release Celebration Policy A.pdf',
#  'DEK Technologies ICT Policy.pdf',
#  'DEK Technologies Quality Policy.pdf',
#  'DEK Technologies Vietnam Time Reporting Policy.pdf',
#  'DEK Technologies Anti-Corruption and Anti-Bribery Policy.pdf',
#  'DEK Technologies Vietnam Performance Evaluation Policy.pdf',
#  'DEK Technologies Vietnam Gifts Frequency Policy.pdf',
#  'DEK_Technologies_Vietnam_Travel_Allowances_Schedule.pdf',
#  'DEK Technologies Vietnam Salary Exchange Rate Policy.pdf',
#  'DEK Technologies Employee ICT Policy and Procedure.pdf',
#  'DEK Technologies Vietnam Escalation Policy.pdf',
#  'DEK Technologies Vietnam Relaxation Areas Policy.pdf',
#  'DEK Technologies Vietnam Overtime Policy.pdf',
#  'DEK Technologies Personal Data Policy.pdf',
#  'DEK Technologies Employee ICT Policy and Procedure.pdf',
#  'DEK Technologies Vietnam Annual Trip Policy.pdf',
#  'DEK Technologies Vietnam Travel Allowance Schedule D.pdf',
#  'DEK Technologies Vietnam ICT Policy.pdf',
#  'DEK Technologies Vietnam Recruitment Referral Policy.pdf',
#  'DEK Technologies Vietnam Trade Union Policy.pdf',
#  'DEK Export Control Policy.pdf',
#  'DEK Technologies Vietnam Accidental Death & Disability and Health Insurance Policy.pdf',
#  'DEK Technologies Vietnam Work From Home Policy.pdf',
#  'DEK Export Control Policy.pdf',
#  'DEK Technologies Vietnam Team Building Policy.pdf',
#  'DEK Technologies Vietnam Accidental Death & Disability and Health Insurance Policy.pdf',
#  'DEK Technologies Personal Data Policy.pdf',
#  'DEK-Technologies-Vietnam-13th-month-Bonus-Regulation_A.pdf',
#  'DEK Technologies Vietnam TOIL Policy.pdf',
#  'DEK-Technologies-Vietnam-13th-month-Bonus-Regulation_A.pdf',
#  'DEK Technologies Vietnam Tuition Reimbursement Policy B.pdf',
#  'DEK Technologies Vietnam Family Day Policy.pdf',
#  'DEK Technologies Vietnam Work From Home Policy.pdf',
#  'DEK Technologies Vietnam Passing-away Policy.pdf',
#  'DEK Technologies Vietnam Office Access Policy.pdf',
#  'DEK Technologies Vietnam Relaxation Areas Policy.pdf',
#  'DEK Technologies Vietnam Office Transfer Policy.pdf',
#  'DEK Technologies Vietnam Work From Home Policy.pdf',
#  'DEK-Technologies-Vietnam-13th-month-Bonus-Regulation_A.pdf',
#  'DEK Technologies Vietnam Probation Period Policy.pdf',
#  'DEK Technologies Vietnam Overtime Policy.pdf',
#  'DEK-Technologies-Vietnam-Code-of-Conduct-Policy-Vietnamese-version.pdf',
#  'DEK-Technologies-Vietnam-International-Travel-Policy-D.pdf',
#  'DEK Technologies Vietnam Annual Trip Policy.pdf',
#  'DEK Technologies Vietnam Visitor Policy.pdf',
#  'DEK Technologies Vietnam ICT Policy.pdf',
#  'DEK Technologies Vietnam Internal Trainer Development Policy A.pdf',
#  'DEK-Technologies-Vietnam-Office-Transfer-Policy_B.pdf',
#  'DEK-Technologies-Vietnam-International-Travel-Policy-D.pdf',
#  'DEK Export Control Policy.pdf',
#  'DEK Technologies Vietnam Remote Work Policy A.pdf',
#  'DEK-Technologies-Vietnam-Office-Transfer-Policy_B.pdf',
#  'DEK Technologies Personal Data Policy.pdf',
#  'DEK Technologies Vietnam Feedback Sharing Policy.pdf',
#  'DEK Technologies Personal Data Policy.pdf',
#  'DEK Technologies Vietnam Travel Policy.pdf',
#  'DEK Technologies Vietnam ICT Policy.pdf',
#  'DEK Technologies Vietnam Family Day Policy.pdf',
#  'DEK Technologies Vietnam Hybrid Policy A.pdf',
#  'DEK Technologies Vietnam Internal Trainer Development Policy A.pdf',
#  'DEK Technologies Vietnam Working Hours Policy.pdf',
#  'DEK Technologies Vietnam Visitor Policy.pdf',
#  'DEK Technologies Vietnam Health & Safety Policy.pdf',
#  'DEK Technologies Vietnam Working Hours Policy.pdf',
#  'DEK Technologies Vietnam 1on1 Policy A.pdf',
#  'DEK Technologies Vietnam Disciplinary Policy.pdf',
#  'DEK Technologies Vietnam Foundation Policy.pdf',
#  'DEK Technologies Vietnam International Travel Policy C.pdf',
#  'DEK Technologies Employee ICT Policy and Procedure.pdf',
#  'DEK Technologies Vietnam Health & Safety Policy.pdf',
#  'DEK Technologies Vietnam International Travel Policy C.pdf',
#  'DEK Technologies ICT Policy.pdf',
#  'DEK Technologies Vietnam Time Reporting Policy.pdf',
#  'DEK Technologies Anti-Corruption and Anti-Bribery Policy.pdf',
#  'DEK Technologies Vietnam Escalation Policy.pdf',
#  'DEK Technologies Vietnam Confidentiality Policy.pdf',
#  'DEK Technologies Vietnam Internal Trainer Development Policy A.pdf',
#  'DEK_Technologies_Vietnam_Travel_Allowances_Schedule.pdf',
#  'DEK Technologies Human Resources Policy.pdf',
#  'DEK Technologies Anti-Corruption and Anti-Bribery Policy.pdf',
#  'DEK Technologies Personal Data Policy.pdf',
#  'DEK Technologies Vietnam Code of Conduct Policy.pdf',
#  'DEK-Technologies-Vietnam-Office-Transfer-Policy_B.pdf',
#  'DEK Technologies Vietnam Travel Allowance Schedule D.pdf',
#  'DEK Technologies Vietnam TOIL Policy.pdf',
#  'DEK Technologies Vietnam Domestic Travel Policy A.pdf',
#  'DEK Technologies Vietnam Salary Exchange Rate Policy.pdf',
#  'DEK Technologies Vietnam Gifts Frequency Policy.pdf',
#  'DEK-Technologies-Vietnam-International-Travel-Policy-D.pdf',
#  'DEK Technologies ICT Policy.pdf',
#  'DEK Technologies Vietnam Fresher Training Period Policy.pdf',
#  'DEK_Technologies_Vietnam_On-Call_Support_Service_Policy.pdf',
#  'DEK Technologies Vietnam Environmental Policy.pdf',
#  'DEK Technologies Vietnam Trade Union Policy.pdf',
#  'DEK Technologies Vietnam Project Release Celebration Policy A.pdf',
#  'DEK Technologies Vietnam Code of Conduct Policy.pdf',
#  'DEK Technologies Vietnam International Travel Policy C.pdf',
#  'DEK Technologies Vietnam New Team Kick Off Policy A.pdf',
#  'DEK Technologies Vietnam Office Access Policy.pdf',
#  'DEK Technologies Vietnam Leave Policy.pdf',
#  'DEK Technologies Vietnam Tuition Reimbursement Policy A.pdf',
#  'DEK_Technologies_Vietnam_On-Call_Support_Service_Policy.pdf',
#  'DEK Technologies Employee ICT Policy and Procedure.pdf',
#  'DEK Technologies Vietnam Recruitment Referral Policy.pdf',
#  'DEK Technologies Vietnam Office Transfer Policy.pdf',
#  'DEK Technologies Vietnam Time Reporting Policy.pdf',
#  'DEK Technologies Vietnam Disciplinary Policy.pdf',
#  'DEK Technologies Vietnam Health & Safety Policy.pdf',
#  'DEK Technologies Vietnam Internal Trainer Development Policy A.pdf',
#  'DEK Technologies Vietnam Environmental Policy.pdf',
#  'DEK Technologies Human Resources Policy.pdf']

# %%
from collections import Counter
import pandas as pd

counter = Counter(files)
df = pd.DataFrame.from_dict(counter, orient='index').reset_index()
df = df.rename(columns={'index':'file name', 0:'count'})
df
# Out:
#                                             file name  count
# 0   DEK-Technologies-Vietnam-Code-of-Conduct-Polic...      2
# 1          DEK Technologies Vietnam Travel Policy.pdf      2
# 2                 DEK Technologies Quality Policy.pdf      3
# 3     DEK Technologies Vietnam Annual Trip Policy.pdf      3
# 4          DEK Technologies Vietnam 1on1 Policy A.pdf      2
# 5           DEK Technologies Vietnam Leave Policy.pdf      2
# 6   DEK Technologies Vietnam Performance Evaluatio...      2
# 7        DEK Technologies Vietnam Hybrid Policy A.pdf      3
# 8   DEK Technologies Vietnam Fresher Training Peri...      3
# 9   DEK Technologies Vietnam Remote Work Policy A.pdf      2
# 10  DEK Technologies Vietnam Recruitment Referral ...      3
# 11        DEK Technologies Human Resources Policy.pdf      4
# 12  DEK Technologies Vietnam Office Access Policy.pdf      3
# 13     DEK Technologies Vietnam Foundation Policy.pdf      2
# 14  DEK Technologies Vietnam Domestic Travel Polic...      2
# 15  DEK Technologies Employee ICT Policy and Proce...      5
# 16  DEK Technologies Vietnam Probation Period Poli...      2
# 17  DEK Technologies Vietnam New Team Kick Off Pol...      2
# 18   DEK Technologies Vietnam Passing-away Policy.pdf      2
# 19     DEK Technologies Vietnam Escalation Policy.pdf      3
# 20  DEK Technologies Vietnam Team Building Policy.pdf      2
# 21  DEK Technologies Vietnam Feedback Sharing Poli...      2
# 22  DEK Technologies Vietnam Salary Exchange Rate ...      3
# 23  DEK Technologies Vietnam Confidentiality Polic...      2
# 24                    DEK Technologies ICT Policy.pdf      4
# 25  DEK Technologies Vietnam Project Release Celeb...      2
# 26  DEK Technologies Vietnam Time Reporting Policy...      3
# 27  DEK Technologies Anti-Corruption and Anti-Brib...      3
# 28  DEK Technologies Vietnam Gifts Frequency Polic...      2
# 29  DEK_Technologies_Vietnam_Travel_Allowances_Sch...      2
# 30  DEK Technologies Vietnam Relaxation Areas Poli...      2
# 31       DEK Technologies Vietnam Overtime Policy.pdf      2
# 32          DEK Technologies Personal Data Policy.pdf      5
# 33  DEK Technologies Vietnam Travel Allowance Sche...      2
# 34            DEK Technologies Vietnam ICT Policy.pdf      3
# 35    DEK Technologies Vietnam Trade Union Policy.pdf      2
# 36                      DEK Export Control Policy.pdf      3
# 37  DEK Technologies Vietnam Accidental Death & Di...      2
# 38  DEK Technologies Vietnam Work From Home Policy...      3
# 39  DEK-Technologies-Vietnam-13th-month-Bonus-Regu...      3
# 40           DEK Technologies Vietnam TOIL Policy.pdf      2
# 41  DEK Technologies Vietnam Tuition Reimbursement...      1
# 42     DEK Technologies Vietnam Family Day Policy.pdf      2
# 43  DEK Technologies Vietnam Office Transfer Polic...      2
# 44  DEK-Technologies-Vietnam-International-Travel-...      3
# 45        DEK Technologies Vietnam Visitor Policy.pdf      2
# 46  DEK Technologies Vietnam Internal Trainer Deve...      4
# 47  DEK-Technologies-Vietnam-Office-Transfer-Polic...      3
# 48  DEK Technologies Vietnam Working Hours Policy.pdf      2
# 49  DEK Technologies Vietnam Health & Safety Polic...      3
# 50   DEK Technologies Vietnam Disciplinary Policy.pdf      2
# 51  DEK Technologies Vietnam International Travel ...      3
# 52  DEK Technologies Vietnam Code of Conduct Polic...      2
# 53  DEK_Technologies_Vietnam_On-Call_Support_Servi...      2
# 54  DEK Technologies Vietnam Environmental Policy.pdf      2
# 55  DEK Technologies Vietnam Tuition Reimbursement...      1

# %%
df.loc[df['count'].idxmin()]
# Out:
# file name    DEK Technologies Vietnam Tuition Reimbursement...
# count                                                        1
# Name: 41, dtype: object

# %%
df.loc[df['count'].idxmax()]
# Out:
# file name    DEK Technologies Employee ICT Policy and Proce...
# count                                                        5
# Name: 15, dtype: object

# %%
df['count'].median()
# Out:
# 2.0
